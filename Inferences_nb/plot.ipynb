# %%
import os
import time
import numpy as np
import pandas as pd
import operator

import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# !pip install kornia
# Out:
# ...
#      |████████████████████████████████| 286kB 4.0MB/s
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/Shareddrives/Disk1/InfoPro-Pytorch/Experiments on CIFAR-SVHN-STL10
# Out:
# /content/gdrive/Shareddrives/Disk1/InfoPro-Pytorch/Experiments on CIFAR-SVHN-STL10

# %%
# %%shell
# CUDA_VISIBLE_DEVICES=0 python train_data.py --dataset cifar10 --model resnet --layers 32 --droprate 0.0 --cos_lr --local_module_num 2  --local_loss_mode cross_entropy --aux_net_widen 1 --aux_net_feature_dim 128 --alpha_1 5 --beta_1 2.0 --beta_2 1.0 --ixx_2 0 --ixy_2 0 --gamma_1 1.5 --gamma_2 0.0 --aux_net_config 1c2f
# Out:
# Storing in ... ./InfoPro_cifar10_resnet32_K_2_/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_2.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0_skewness_rate_0.5batchsize_64_small
# Files already downloaded and verified
# Files already downloaded and verified
# No of samples used (1000,) and unused (8800,)
# No of samples used (2000,) and unused (0,)
# Worker 1 Set:-
# Label 1 samples =  250  Label 2 samples =  250
# Worker 2 Set:-
# Label 1 samples =  250  Label 2 samples =  750
# W1 Epoch: [0][1/8]	Time 2.702 (2.702)	Loss 1.0180 (1.0180)	Prec@1 53.125 (53.125)
# W2 Epoch: [0][1/8]	Time 2.702 (2.702)	Loss 0.9814 (0.9814)	Prec@1 9.375 (9.375)
# W1 Epoch: [0][2/8]	Time 2.566 (2.634)	Loss 0.8484 (0.9332)	Prec@1 57.812 (55.469)
# W2 Epoch: [0][2/8]	Time 2.566 (2.634)	Loss 0.8651 (0.9232)	Prec@1 15.625 (12.500)
# W1 Epoch: [0][3/8]	Time 2.460 (2.576)	Loss 1.1756 (1.0140)	Prec@1 40.625 (50.521)
# ...

# %%
# %%shell
# CUDA_VISIBLE_DEVICES=0 python train_data.py --dataset cifar10 --model resnet --layers 32 --droprate 0.0 --cos_lr --local_module_num 2  --local_loss_mode cross_entropy --aux_net_widen 1 --aux_net_feature_dim 128 --alpha_1 5 --beta_1 1.0 --beta_2 1.0 --ixx_2 0 --ixy_2 0 --gamma_1 1.5 --gamma_2 0.0 --aux_net_config 1c2f
# Out:
# Streaming output truncated to the last 5000 lines.
# W1 Epoch: [16][2/71]	Time 0.449 (0.468)	Loss 0.4403 (0.4991)	Prec@1 75.000 (75.000)
# W2 Epoch: [16][2/71]	Time 0.449 (0.468)	Loss 0.4379 (0.4778)	Prec@1 81.250 (79.688)
# W1 Epoch: [16][3/71]	Time 0.443 (0.460)	Loss 0.5344 (0.5109)	Prec@1 73.438 (74.479)
# W2 Epoch: [16][3/71]	Time 0.443 (0.460)	Loss 0.4669 (0.4741)	Prec@1 79.688 (79.688)
# W1 Epoch: [16][4/71]	Time 0.457 (0.459)	Loss 0.2825 (0.4538)	Prec@1 90.625 (78.516)
# W2 Epoch: [16][4/71]	Time 0.457 (0.459)	Loss 0.4192 (0.4604)	Prec@1 79.688 (79.688)
# W1 Epoch: [16][5/71]	Time 0.463 (0.460)	Loss 0.5782 (0.4787)	Prec@1 73.438 (77.500)
# W2 Epoch: [16][5/71]	Time 0.463 (0.460)	Loss 0.5214 (0.4726)	Prec@1 71.875 (78.125)
# W1 Epoch: [16][6/71]	Time 0.493 (0.465)	Loss 0.6998 (0.5155)	Prec@1 71.875 (76.562)
# W2 Epoch: [16][6/71]	Time 0.493 (0.465)	Loss 0.7471 (0.5183)	Prec@1 60.938 (75.260)
# W1 Epoch: [16][7/71]	Time 0.436 (0.461)	Loss 0.3709 (0.4949)	Prec@1 85.938 (77.902)
# ...

# %%
# %%shell
# CUDA_VISIBLE_DEVICES=0 python train_data.py --dataset cifar10 --model resnet --layers 32 --droprate 0.0 --cos_lr --local_module_num 2  --local_loss_mode cross_entropy --aux_net_widen 1 --aux_net_feature_dim 128 --alpha_1 5 --beta_1 1.0 --beta_2 1.0 --ixx_2 0 --ixy_2 0 --gamma_1 2.0 --gamma_2 0.0 --aux_net_config 1c2f
# Out:
# Streaming output truncated to the last 5000 lines.
# W1 Epoch: [16][2/71]	Time 0.439 (0.453)	Loss 0.4714 (0.4945)	Prec@1 79.688 (79.688)
# W2 Epoch: [16][2/71]	Time 0.439 (0.453)	Loss 0.4527 (0.4456)	Prec@1 84.375 (78.125)
# W1 Epoch: [16][3/71]	Time 0.431 (0.446)	Loss 0.6254 (0.5381)	Prec@1 73.438 (77.604)
# W2 Epoch: [16][3/71]	Time 0.431 (0.446)	Loss 0.4043 (0.4318)	Prec@1 82.812 (79.688)
# W1 Epoch: [16][4/71]	Time 0.436 (0.443)	Loss 0.2835 (0.4745)	Prec@1 89.062 (80.469)
# W2 Epoch: [16][4/71]	Time 0.436 (0.443)	Loss 0.4015 (0.4243)	Prec@1 79.688 (79.688)
# W1 Epoch: [16][5/71]	Time 0.460 (0.447)	Loss 0.4678 (0.4731)	Prec@1 75.000 (79.375)
# W2 Epoch: [16][5/71]	Time 0.460 (0.447)	Loss 0.5030 (0.4400)	Prec@1 73.438 (78.438)
# W1 Epoch: [16][6/71]	Time 0.710 (0.491)	Loss 0.6512 (0.5028)	Prec@1 68.750 (77.604)
# W2 Epoch: [16][6/71]	Time 0.710 (0.491)	Loss 0.5600 (0.4600)	Prec@1 73.438 (77.604)
# W1 Epoch: [16][7/71]	Time 0.434 (0.483)	Loss 0.2829 (0.4714)	Prec@1 89.062 (79.241)
# ...

# %%
# %%shell
# CUDA_VISIBLE_DEVICES=0 python train_data.py --dataset cifar10 --model resnet --layers 32 --droprate 0.0 --cos_lr --local_module_num 2  --local_loss_mode cross_entropy --aux_net_widen 1 --aux_net_feature_dim 128 --alpha_1 5 --beta_1 1.0 --beta_2 1.0 --ixx_2 0 --ixy_2 0 --gamma_1 1.0 --gamma_2 0.0 --aux_net_config 1c2f
# Out:
# Streaming output truncated to the last 5000 lines.
# W1 Epoch: [16][2/71]	Time 0.466 (0.469)	Loss 0.4889 (0.5122)	Prec@1 78.125 (76.562)
# W2 Epoch: [16][2/71]	Time 0.466 (0.469)	Loss 0.4336 (0.4400)	Prec@1 79.688 (79.688)
# W1 Epoch: [16][3/71]	Time 3.551 (1.497)	Loss 0.6118 (0.5454)	Prec@1 67.188 (73.438)
# W2 Epoch: [16][3/71]	Time 3.551 (1.497)	Loss 0.5161 (0.4654)	Prec@1 76.562 (78.646)
# W1 Epoch: [16][4/71]	Time 0.450 (1.235)	Loss 0.2433 (0.4699)	Prec@1 87.500 (76.953)
# W2 Epoch: [16][4/71]	Time 0.450 (1.235)	Loss 0.4446 (0.4602)	Prec@1 81.250 (79.297)
# W1 Epoch: [16][5/71]	Time 0.565 (1.101)	Loss 0.4540 (0.4667)	Prec@1 81.250 (77.812)
# W2 Epoch: [16][5/71]	Time 0.565 (1.101)	Loss 0.5085 (0.4699)	Prec@1 71.875 (77.812)
# W1 Epoch: [16][6/71]	Time 0.772 (1.046)	Loss 0.6932 (0.5045)	Prec@1 67.188 (76.042)
# W2 Epoch: [16][6/71]	Time 0.772 (1.046)	Loss 0.5930 (0.4904)	Prec@1 70.312 (76.562)
# W1 Epoch: [16][7/71]	Time 0.519 (0.971)	Loss 0.2877 (0.4735)	Prec@1 89.062 (77.902)
# ...

# %% [markdown]
# #plotting

# %%
names = ["index", "time", "loss", "accuracy", "dump"]

def traindata(df1,df2):
  lis=[df2.loc[df2['index']==x,:] for x in df2['index'] if operator.contains(x,'Val')]
  df2_val=pd.DataFrame(np.array(lis).reshape(-1,5),columns=names)

  lis=[df2.loc[df2['index']==x,:] for x in df2['index'] if operator.contains(x,'Epoch')]
  df2=pd.DataFrame(np.array(lis).reshape(-1,5),columns=names)
  
  lis=[df1.loc[df1['index']==x,:] for x in df1['index'] if operator.contains(x,'Val')]
  df1_val=pd.DataFrame(np.array(lis).reshape(-1,5),columns=names)

  lis=[df1.loc[df1['index']==x,:] for x in df1['index'] if operator.contains(x,'Epoch')]
  df1=pd.DataFrame(np.array(lis).reshape(-1,5),columns=names)
  return df1,df1_val,df2,df2_val

# %% [markdown]
# #gamma_1=0.25

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.25_gamma_2_0.0batchsize_512/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.25_gamma_2_0.0batchsize_512/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=9
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("gamma_1=0.25")
# Out:
# (450, 5)
# Text(0.5, 1.0, 'gamma_1=0.25')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.25_gamma_2_0.0batchsize_512/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.25_gamma_2_0.0batchsize_512/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Loss")
plt.plot(l4, label = "Worker 2 Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=0.25')
# Out:
# Text(0.5, 1.0, 'gamma_1=0.25')

# %% [markdown]
# #gamma_1=0.5

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.5_gamma_2_0.0batchsize_512/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.5_gamma_2_0.0batchsize_512/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=9
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=0.5')
# Out:
# (450, 5)
# Text(0.5, 1.0, 'gamma_1=0.5')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.5_gamma_2_0.0batchsize_512/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.5_gamma_2_0.0batchsize_512/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Loss")
plt.plot(l4, label = "Worker 2 Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=0.5')
# Out:
# Text(0.5, 1.0, 'gamma_1=0.5')

# %% [markdown]
# #gamma_1=1

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.0_gamma_2_0.0batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.0_gamma_2_0.0batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.0')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=1.0')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.0_gamma_2_0.0batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.0_gamma_2_0.0batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Loss")
plt.plot(l4, label = "Worker 2 Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.0')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.0')

# %% [markdown]
# #gamma_1=1.5

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.5')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=1.5')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Loss")
plt.plot(l4, label = "Worker 2 Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.5')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.5')

# %% [markdown]
# #gamma_1=2

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_2.0_gamma_2_0.0batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_2.0_gamma_2_0.0batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=2.0')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=2.0')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_2.0_gamma_2_0.0batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_2.0_gamma_2_0.0batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Loss")
plt.plot(l4, label = "Worker 2 Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=2.0')
# Out:
# Text(0.5, 1.0, 'gamma_1=2.0')

# %% [markdown]
# ## Gamma_1 = 1.5, Gamma_2 = 0.5

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.5batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.5batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.5, gamma_2=0.5')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=0.5')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.5batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.5batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Loss")
plt.plot(l4, label = "Worker 2 Loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.5, gamma_2=0.5')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=0.5')

# %% [markdown]
# ### gamma_1 = 1.5, gamma_2 = 1.0

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.0batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.0batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.5, gamma_2=1.0')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=1.0')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.0batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.0batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Acc")
plt.plot(l4, label = "Worker 2 Acc")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.5, gamma_2=1.0')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=1.0')

# %% [markdown]
# ### gamma 1=1.5, gamma_2 = 1.5

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.5batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.5batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.5, gamma_2=1.5')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=1.5')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.5batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_1.5batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Acc")
plt.plot(l4, label = "Worker 2 Acc")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.5, gamma_2=1.5')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=1.5')

# %% [markdown]
# ### gamma_1 = 1.5, gamma_2 = 2.0

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_2.0batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_2.0batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.5, gamma_2=2.0')
# Out:
# (3550, 5)
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=2.0')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_2.0batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_2.0batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Acc")
plt.plot(l4, label = "Worker 2 Acc")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.5, gamma_2=2.0')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.5, gamma_2=2.0')

# %% [markdown]
# #beta_1=2,gamma_1=1.5

# %%
path1='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_2.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0batchsize_64/training_process1.txt'
path2='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_2.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_0.0batchsize_64/training_process2.txt'

df1 = pd.read_csv(path1, sep="\t", header=None, names=names)
df2 = pd.read_csv(path2, sep="\t", header=None, names=names)
df1=df1.loc[:3550,:].copy()
df2=df2.loc[:3550,:].copy()

df1,df1_val,df2,df2_val=traindata(df1,df2)
print(df1.shape)
l1 = []
l2 = []
l1_val = []
l2_val = []
batchs=71
i=-1

for element1, element2 in zip(df1.loss, df2.loss):
  i+=1
  if i%batchs==0:
    ele1 = element1.split("(")
    ele2 = element2.split("(")
    ele1 = ele1[1].split(")")
    ele2 = ele2[1].split(")")
    l1.append(float(ele1[0]))
    l2.append(float(ele2[0]))

for element1_val, element2_val in zip(df1_val.loss, df2_val.loss):
  ele1_val = element1_val.split("(")
  ele2_val = element2_val.split("(")
  ele1_val = ele1_val[1].split(")")
  ele2_val = ele2_val[1].split(")")
  l1_val.append(float(ele1_val[0]))
  l2_val.append(float(ele2_val[0]))

plt.plot(l1, label = "Worker 1 train Loss",c='orange')
plt.plot(l2, label = "Worker 2 train Loss",c='maroon')
plt.plot(l1_val, label = "Worker 1 val Loss",c='red')
plt.plot(l2_val, label = "Worker 2 val Loss",c='black')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('gamma_1=1.5, beta_1=2.0')
# Out:
# (3502, 5)
# Text(0.5, 1.0, 'gamma_1=1.5, beta_1=2.0')

# %%
path3='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_2.0batchsize_64/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet32_K_2_/tuning beta gamma/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_1.5_gamma_2_2.0batchsize_64/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

plt.plot(l3, label = "Worker 1 Acc")
plt.plot(l4, label = "Worker 2 Acc")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.title('gamma_1=1.5, beta_1=2.0')
# Out:
# Text(0.5, 1.0, 'gamma_1=1.5, beta_1=2.0')

# %% [markdown]
# ### Plot of Baseline vs Proposed Val Acc

# %%
plt.figure(figsize = (10, 10))
path3='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/more_epochs/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.0_gamma_2_0.0_skewness_rate_0.5/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/more_epochs/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_1.0_beta_2_1.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.0_gamma_2_0.0_skewness_rate_0.5/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l3 = []
l4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l3.append(element3)
  l4.append(element4)

y = [i for i in range(1000)]
plt.scatter(y,l3,label = "Worker 1 Loss Baseline", alpha=1.0, s=1.5)
plt.scatter(y,l4,label = "Worker 2 Loss Baseline", alpha=1.0, s=1.5)

path3='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/more_epochs/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_20.0_beta_2_20.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_5.0_gamma_2_10.0_skewness_rate_0.5/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/more_epochs/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_20.0_beta_2_20.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_5.0_gamma_2_10.0_skewness_rate_0.5/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l_3 = []
l_4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l_3.append(element3)
  l_4.append(element4)

plt.scatter(y,l_3,label = "Worker 1 Loss", alpha=1.0, s=1.5)
plt.scatter(y,l_4,label = "Worker 2 Loss", alpha=1.0, s=1.5)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.show()

# %%
plt.figure(figsize = (10, 10))
path3='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_20.0_beta_2_20.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.0_gamma_2_0.0_skewness_rate_0.5_baseline/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_20.0_beta_2_20.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_0.0_gamma_2_0.0_skewness_rate_0.5_baseline/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l_3 = []
l_4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l_3.append(element3)
  l_4.append(element4)
y = [i for i in range(100)]
#plt.scatter(y,l_3,label = "Worker 1 Loss", alpha=1.0, s=1.5)
#plt.scatter(y,l_4,label = "Worker 2 Loss", alpha=1.0, s=1.5)
plt.plot(l_3)
plt.plot(l_4)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
#plt.show()

path3='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/more_epochs/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_20.0_beta_2_20.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_5.0_gamma_2_10.0_skewness_rate_0.5/accuracy_epoch1.txt'
path4='./InfoPro_cifar10_resnet16_K_2_/exp_cosine_loss/more_epochs/no_1_aux_net_config_1c2f_local_loss_mode_cross_entropy_aux_net_widen_1.0_aux_net_feature_dim_128_alpha_1_5.0_beta_1_20.0_beta_2_20.0_ixx_2_0.0_ixy_2_0.0_cos_lr__gamma_1_5.0_gamma_2_10.0_skewness_rate_0.5/accuracy_epoch2.txt'
#accuracy
df3 = pd.read_csv(path3, sep="\t", header=None, names = ["acc"])
df4 = pd.read_csv(path4, sep="\t", header=None, names = ["acc"])

l_3 = []
l_4 = []
for element3, element4 in zip(df3.acc, df4.acc):
  l_3.append(element3)
  l_4.append(element4)

#plt.scatter(y,l_3,label = "Worker 1 Loss", alpha=1.0, s=1.5)
#plt.scatter(y,l_4,label = "Worker 2 Loss", alpha=1.0, s=1.5)
plt.plot(l_3)
plt.plot(l_4)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
